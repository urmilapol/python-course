# %% [markdown]
# <a href="https://colab.research.google.com/github/urmilapol/python-course/blob/master/pythonfirst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Solution-1 (with pre-defined Variables)
numl = 30 
num2 = 40 
sum = numl+num2 
print ("the sum of given two number is ", sum)
# Out:
# the sum of given two number is  70

# %%
print('Enter your name:')
x = input()
print('Hello, ' + x)
# Out:
# Enter your name:
# shivaji
# Hello, shivaji

# %%
#Solution-2 (with user-inputs) |
print("enter number one")
numl = input() 
print("enter number two")
num2 = input() 
sum = numl + num2 
print("the sum of the provided two numbers is", sum)
# Out:
# enter number one
# 12
# enter number two
# 24
# the sum of the provided two numbers is 1224

# %% [markdown]
# Values |
# A value can be anything- a number, letter or
# a string, list, boolean, tuple, set, dictionary![exp.png](data:image/png;base64,...)

# %%
type(100)
# Out:
# int

# %%
type(14.34)
# Out:
# float

# %%
type(5+8j)
# Out:
# complex

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type("Hello World")
# Out:
# str

# %%
type("Hi")
# Out:
# str

# %%
type([10,40,60])
# Out:
# list

# %%
type((1,6,2,4))
# Out:
# tuple

# %%
type({6,2,4,5})
# Out:
# set

# %%
type({4:"apple",7:"mango"})
# Out:
# dict

# %% [markdown]
# **Variables **
#
# Variables are containers that store data. In
# python, we dont have to declare the
# variable with its data type to create it. The
# variable gets created when we assign a
# value to it. ![third.png](data:image/png;base64,...)

# %% [markdown]
# ![four.png](data:image/png;base64,...)

# %% [markdown]
# ![fifth.png](data:image/png;base64,...)

# %% [markdown]
# ![sixth.png](data:image/png;base64,...)

# %% [markdown]
# ![seventh.png](data:image/png;base64,...)

# %% [markdown]
# ![tuple.png](data:image/png;base64,...)

# %%
a=10
b=20
print (a,b)
# Out:
# 10 20

# %%
s="hello world"
print (s)
# Out:
# hello world

# %%
#Program to swap two numbers
a=10
b=20
(a,b)=(b,a)
print(a,b)
# Out:
# 20 10

# %% [markdown]
# ![nineth.png](data:image/png;base64,...)

# %% [markdown]
# * Parenthesis can be used to override the precedence of operators.
# The expression within () is evaluated first.
# * For operators with equal precedence, the expression is evaluated from left to right.

# %% [markdown]
# ![tenth.png](data:image/png;base64,...)

# %% [markdown]
# ![eleven.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
https://www.w3schools.com/python/python_datatypes.asp
https://www.w3schools.com/python/python_operators.asp
